# %%
from sklearn import metrics, datasets, model_selection, svm
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

data = datasets.load_iris()

x = data.data
y = data.target

x_train, x_test, y_train, y_test = model_selection.train_test_split(x, y, test_size=0.3)

print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
print(y_test.shape)

svm_model = svm.SVC(kernel='linear', gamma='auto', C=2)
svm_model = svm_model.fit(x_train, y_train)

y_pred = svm_model.predict(x_test)

report = metrics.classification_report(y_test, y_pred)
print(report)
# Out:
# (105, 4)
# (45, 4)
# (105,)
# (45,)
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        12
#            1       1.00      0.95      0.97        19
#            2       0.93      1.00      0.97        14
#
#     accuracy                           0.98        45
#    macro avg       0.98      0.98      0.98        45
# weighted avg       0.98      0.98      0.98        45
#
# (768, 9)
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# ...

# %%
data=pd.read_csv("/content/diabetes.csv")
print(data.shape)
print(data.head())
# Out:
# (768, 9)
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
import pandas as pd
from sklearn import svm, metrics, model_selection

# Assuming 'data' is a pandas DataFrame
x = data.drop('Outcome', axis=1, inplace=False)
y = data['Outcome']

# Split the data into 70% training and 30% testing
x_train, x_test, y_train, y_test = model_selection.train_test_split(x, y, test_size=0.3, random_state=1)
print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
print(y_test.shape)

# Initialize the SVM model with a polynomial kernel
dibts_svm_model = svm.SVC(kernel='poly', gamma='scale', C=1)
# Fit the model to the training data
dibts_svm_model = dibts_svm_model.fit(x_train, y_train)

# Use the trained model to make predictions on the test data
y_pred = dibts_svm_model.predict(x_test)

# Calculate the accuracy of the model
acc = metrics.accuracy_score(y_test, y_pred)
print("Accuracy : ", acc)



conf_mat = metrics.confusion_matrix(y_test, y_pred)
print(conf_mat)
# Out:
# (537, 8)
# (231, 8)
# (537,)
# (231,)
# Accuracy :  0.7878787878787878
# [[139   7]
#  [ 42  43]]

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
path='/content/diabetes.csv'
data=pd.read_csv(path)
print(data.shape)
data.head()
# Out:
# (768, 9)
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
data.tail()
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 763                     0.171   63        0
# 764                     0.340   27        0
# 765                     0.245   30        0
# 766                     0.349   47        1
# 767                     0.315   23        0

# %%
plt.figure(figsize=(10, 4))
axes1 = sns.countplot(data=data, x="Glucose")
for i in axes1.containers:
    axes1.bar_label(i)

# %%
plt.figure(1,figsize = (12,6))
ax = sns.barplot(data = data,x = 'Age',y = 'BMI',hue = 'Insulin')
for i in ax.containers:
  ax.bar_label(i)

# %%
# prompt: create a box plot for the dibetes .csv

# Create a box plot for the 'Glucose' column
plt.figure(figsize=(10, 4))
sns.boxplot(x=data['Glucose'])
sns.boxplot(y=data['Age'])
sns.boxplot(z=data['BMI'])
# Add a title and labels
plt.title('Box Plot of Glucose Levels')
plt.xlabel('Glucose Level')
plt.ylabel('Value')

# Show the plot
plt.show()

# %%
# prompt: create a min age and max ahe bar graph

# Define the minimum and maximum age values
min_age = min(data['Age'])
max_age = max(data['Age'])

# Create the bar graph
plt.bar(['Min Age', 'Max Age'], [min_age, max_age])

# Add a title and labels
plt.title('Min and Max Age')
plt.xlabel('Age')
plt.ylabel('Value')

# Show the plot
plt.show()

# %%
# prompt: show blood presure with respect to age

# Create a scatter plot of blood pressure vs age
plt.scatter(data['Age'], data['BloodPressure'])

# Add a title and labels
plt.title('Blood Pressure vs Age')
plt.xlabel('Age')
plt.ylabel('Blood Pressure')

# Show the plot
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
# prompt: with respect to age create a chart for BMI

plt.figure(figsize=(20, 4))
axes1 = sns.countplot(data=data, x="Age", hue="BMI")
for i in axes1.containers:
    axes1.bar_label(i)

# %%
# prompt: Show a grpah which show how many people has suffer from dibetes

# Count the number of people with and without diabetes
diabetes_count = data['Outcome'].value_counts()[1]
no_diabetes_count = data['Outcome'].value_counts()[0]

# Create a bar chart to show the number of people with and without diabetes
plt.bar(['Diabetes', 'No Diabetes'], [diabetes_count, no_diabetes_count])

# Add a title and labels
plt.title('Number of People with and without Diabetes')
plt.xlabel('Condition')
plt.ylabel('Number of People')

# Show the plot
plt.show()

# %%
# prompt: with the help of age column cretae a bar graph which show 3 category of age young adult and old

# Define the age categories
age_categories = ['Young', 'Adult', 'Old']

# Define the minimum and maximum age for each category
age_ranges = {
    'Young': (0, 30),
    'Adult': (30, 60),
    'Old': (60, 100)
}

# Initialize the counts for each category
category_counts = {
    'Young': 0,
    'Adult': 0,
    'Old': 0
}

# Iterate through the ages in the data
for age in data['Age']:
    # Determine the category for the age
    for category, (min_age, max_age) in age_ranges.items():
        if min_age <= age < max_age:
            category_counts[category] += 1
            break

# Create a bar chart to show the number of people in each category
plt.bar(age_categories, category_counts.values())

# Add a title and labels
plt.title('Number of People in Each Age Category')
plt.xlabel('Age Category')
plt.ylabel('Number of People')

# Show the plot
plt.show()

# %%
# prompt: create a bar graph which show a young age below 30 and middle age 31  <= 45  mature > = 46 <= 65 old age over 65

# Define the age categories
age_categories = ['Young', 'Middle', 'Mature', 'Old']

# Define the minimum and maximum age for each category
age_ranges = {
    'Young': (0, 30),
    'Middle': (31, 45),
    'Mature': (46, 65),
    'Old': (65, 100)
}

# Initialize the counts for each category
category_counts = {
    'Young': 0,
    'Middle': 0,
    'Mature': 0,
    'Old': 0
}

# Iterate through the ages in the data
for age in data['Age']:
    # Determine the category for the age
    for category, (min_age, max_age) in age_ranges.items():
        if min_age <= age < max_age:
            category_counts[category] += 1
            break

# Create a bar chart to show the number of people in each category
plt.bar(age_categories, category_counts.values())

# Add a title and labels
plt.title('Number of People in Each Age Category')
plt.xlabel('Age Category')
plt.ylabel('Number of People')

# Show the plot
plt.show()

# %%
data['Age_category'] =data['Age'].copy()
data.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome  Age_category
# 0                     0.627   50        1            50
# 1                     0.351   31        0            31
# 2                     0.672   32        1            32
# 3                     0.167   21        0            21
# 4                     2.288   33        1            33

# %%
import seaborn as sns
data['Age_category'] =data['Age'].copy()
ind = data['Age']<=30
data.loc[ind,'Age_category'] = "Young"
ind = (data['Age']<=45) & (data['Age']>30)
data.loc[ind,'Age_category'] = "Middle-Age"
ind = (data['Age']<=65) & (data['Age']>45)
data.loc[ind,'Age_category'] = "Mature-Age"
ind = (data['Age']>65)
data.loc[ind,'Age_category'] = "Old-Age"
data.head()
plt.figure(1,(4,4))
sns.countplot(data=data,x='Age_category',hue='Outcome')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-b56bff3072ef> in <cell line: 2>()
#       1 import seaborn as sns
# ----> 2 data['Age_category'] =data['Age'].copy()
#       3 ind = data['Age']<=30
#       4 data.loc[ind,'Age_category'] = "Young"
#       5 ind = (data['Age']<=45) & (data['Age']>30)
#
# NameError: name 'data' is not defined

# %%
import pandas as pd
import numpy as np

data= pd.read_csv("/content/diabetes.csv")
print(data.shape)
data.head()
# X will be holding all the feature columns
X = data.drop('Outcome',axis=1,inplace=False)

# y will be holding all the labels column
y = data['Outcome']


# split the data into 70:30 ratio
Xtrain,Xtest,ytrain,ytest = model_selection.train_test_split(X,y,test_size=0.3,random_state=5)
print(Xtrain.shape,ytrain.shape)
print(Xtest.shape,ytest.shape)

ker = ['poly','linear','rbf']
c_value = [1,2,3]

# pre allocation of the result variable
result = np.zeros((len(ker),len(c_value)))
for i in range(len(ker)):
  for j in range(len(c_value)):
    # create the svm classifier
    dibts_svm_model = svm.SVC(kernel=ker[i],gamma='scale',C=c_value[j])

    # train the model
    dibts_svm_model = dibts_svm_model.fit(Xtrain,ytrain)

    # predict the labels
    ypred = dibts_svm_model.predict(Xtest)

    # accuracy
    acc = metrics.accuracy_score(ypred,ytest)
    #print("accuracy:", acc)
    result[i,j]=acc
print(result)

ResultDF = pd.DataFrame(result,index=ker,columns=["C=1","C=2","C=3"])
# Out:
# (768, 9)
# (537, 8) (537,)
# (231, 8) (231,)
# [[0.78787879 0.78787879 0.77922078]
#  [0.7965368  0.7965368  0.7965368 ]
#  [0.78354978 0.77489177 0.76623377]]

# %%
import pandas as pd
import numpy as np

data= pd.read_csv("/content/Fish.csv")
print(data.shape)
data.head()
# X will be holding all the feature columns
X = data.drop('Species',axis=1,inplace=False)

# y will be holding all the labels column
y = data['Species']


# split the data into 70:30 ratio
Xtrain,Xtest,ytrain,ytest = model_selection.train_test_split(X,y,test_size=0.3,random_state=5)
print(Xtrain.shape,ytrain.shape)
print(Xtest.shape,ytest.shape)

ker = ['poly','linear','rbf']
c_value = [1,2,3]

# pre allocation of the result variable
result = np.zeros((len(ker),len(c_value)))
for i in range(len(ker)):
  for j in range(len(c_value)):
    # create the svm classifier
    dibts_svm_model = svm.SVC(kernel=ker[i],gamma='scale',C=c_value[j])

    # train the model
    dibts_svm_model = dibts_svm_model.fit(Xtrain,ytrain)

    # predict the labels
    ypred = dibts_svm_model.predict(Xtest)

    # accuracy
    acc = metrics.accuracy_score(ypred,ytest)
    #print("accuracy:", acc)
    result[i,j]=acc
print(result)

ResultDF = pd.DataFrame(result,index=ker,columns=["C=1","C=2","C=3"])
ResultDF = ResultDF.T
print(ResultDF)
ResultDF.plot(kind='bar',figsize=(4,4))
# Out:
# (159, 7)
# (111, 6) (111,)
# (48, 6) (48,)
# [[0.3125     0.3125     0.33333333]
#  [0.85416667 0.875      0.85416667]
#  [0.47916667 0.4375     0.4375    ]]
#          poly    linear       rbf
# C=1  0.312500  0.854167  0.479167
# C=2  0.312500  0.875000  0.437500
# C=3  0.333333  0.854167  0.437500
# <Axes: >

# %%
from sklearn import metrics,datasets,model_selection,svm
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(1,figsize=(13,7))
sns.boxplot(data=data)
# Out:
# <Axes: >
